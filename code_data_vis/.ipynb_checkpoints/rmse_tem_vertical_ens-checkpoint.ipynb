# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
#import os
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
import matplotlib.patches as patches
import os
import cartopy.mpl.ticker as cticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import re
import datetime
import pandas as pd
import matplotlib.dates as mdates
import dask.array as da
import seaborn as sns

import dask

# %%
########################################################## load the fcnv2_ec_ens ####################################################################################

# %%
import xarray as xr
import os
import numpy as np

# Base directory and dataset directory
base_directory = '/pfs/work7/workspace/scratch/gj5173-ws_ai_models/'
dataset_directory = 'ifs/'
date_str = '20210616'
file_pattern = os.path.join(base_directory, dataset_directory, date_str, 'forecasts', f'fcnv2_fc_ifs_{date_str}_0000_m*.nc')
ds_fcnv2_ec_0616_ens = xr.open_mfdataset(file_pattern, concat_dim='member', combine='nested', chunks={'time': 10, 'height_3':1,'lat': 100, 'lon': 100}, engine='netcdf4')
#ds_fcnv2_ec_0616_cf = xr.open_mfdataset(file_pattern, chunks={'time': 10, 'height_3':1,'lat': 100, 'lon': 100}, engine='netcdf4')
# Select the variable and the desired slice
# Adjust indices according to your needs
#ds_selected = ds['2t'].isel(time=51, height_3 =0, lat=slice(40, 261), lon=slice(720, 1201))

# Load the data if necessary, or use Dask for lazy evaluation and parallel processing
# data = ds_selected.compute()  # Uncomment this line if you need to load data into memory, otherwise, you can work with lazy-loaded dask arrays
# Out:
# /home/kit/imk-tro/gj5173/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/concat.py:546: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))

# %%
ds_fcnv2_ec_0616_ens_tL9_landbox = ds_fcnv2_ec_0616_ens.t.isel(time = slice(31,60,4),plev=[1, 3, 4, 5, 6, 7, 8, 9, 10],lat =slice(164,123,-1),lon=slice(940,981))
#choose certain time and plevs
#ds_fcnv2_ec_0616_cf_tL9_landbox = ds_fcnv2_ec_0616_cf.t.isel(time = slice(31,60,4),plev=[1, 3, 4, 5, 6, 7, 8, 9, 10],lat =slice(164,123,-1),lon=slice(940,981))
#ds_fcnv2_ec_0616_cf_tL9_landbox_mean = np.mean(ds_fcnv2_ec_0616_cf_tL9_landbox,axis=(-1,-2))

ds_fcnv2_ec_0616_ens_tL9_landbox_mean = np.mean(ds_fcnv2_ec_0616_ens_tL9_landbox,axis=(-1,-2))

ds_fcnv2_ec_0616_ens_tL9_landbox_mean
# Out:
# <xarray.DataArray 't' (member: 50, time: 8, plev: 9)>
# dask.array<mean_agg-aggregate, shape=(50, 8, 9), dtype=float32, chunksize=(1, 3, 9), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2021-06-24 2021-06-25 ... 2021-07-01
#   * plev     (plev) float64 1e+04 2e+04 2.5e+04 3e+04 ... 6e+04 7e+04 8.5e+04
# Dimensions without coordinates: member

# %%
########################################################load climatology ##############################################################################################

# %%
levels = [10000, 20000,25000,30000,40000,50000,60000,70000,80000,85000,90000]
base_pattern = '/home/kit/imk-tro/gj5173/tmp/clim_T{level}_30day_centered_on_0629_1979-2020_-180.0--60.0degE_25.0-80.0degN_by_grid_point'
datasets = []

for level in levels:
    filename = base_pattern.format(level=level)  
    ds = xr.open_dataset(filename,engine='netcdf4')
    datasets.append(ds)

ds_clim_T_100_900 = xr.concat(datasets, dim='plev')

# %%
ds_clim_T_L9_landbox = ds_clim_T_100_900.isel(plev=[0,1,2,3,4,5,6,7,9],lat =slice(48, 69),lon=slice(110,131))
ds_clim_T_L9_mean = np.mean(ds_clim_T_L9_landbox.T,axis=(-1,-2))

# %%
################################################ load era5 data ########################################################################################################

# %%
ds_era5_JJ = xr.open_dataset('/home/kit/imk-tro/gj5173/ai-models/data/era5_2021-JJ.nc')
ds_era5_JJ_T = ds_era5_JJ['var130']

ds_era5_JJ_T_landbox = ds_era5_JJ_T[:,:,164:123:-1,940:981] #area from 49N-59N,115W-125W
ds_era5_0624_0701_t_landbox = ds_era5_JJ_T_landbox.isel(plev=[1, 3, 4, 5, 6, 7, 8, 9, 10],time=slice(10,18))
ds_era5_0624_0701_t_landbox_mean = np.mean(ds_era5_0624_0701_t_landbox,axis=(-1,-2))

# %%
#################################################### anomaly calculation ###############################################################################################

# %%
ds_anomaly_era5_mean_T_L9_624701_mean = ds_era5_0624_0701_t_landbox_mean - ds_clim_T_L9_mean
ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean = ds_fcnv2_ec_0616_ens_tL9_landbox_mean - ds_clim_T_L9_mean
#ds_anomaly_fcnv2_ec_cf_T_L9_0616_mean = ds_fcnv2_ec_0616_cf_tL9_landbox_mean - ds_clim_T_L9_mean

# %%
ds_anomaly_era5_mean__T_L9_624701_mean
# Out:
# dask.array<array, shape=(8, 9), dtype=float32, chunksize=(4, 3), chunktype=xarray.DataArray>

# %%
ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean
# Out:
# <xarray.DataArray (member: 50, time: 8, plev: 9)>
# dask.array<sub, shape=(50, 8, 9), dtype=float32, chunksize=(1, 3, 9), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2021-06-24 2021-06-25 ... 2021-07-01
#   * plev     (plev) float64 1e+04 2e+04 2.5e+04 3e+04 ... 6e+04 7e+04 8.5e+04
# Dimensions without coordinates: member

# %%
##################################################### calculate RMSE ############################################################################################

# %%
# Compute the squared difference
squared_diff = (ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean - ds_anomaly_era5_mean_T_L9_624701_mean) ** 2

# %%
squared_diff
# Out:
# <xarray.DataArray (member: 50, time: 8, plev: 9)>
# dask.array<pow, shape=(50, 8, 9), dtype=float32, chunksize=(1, 3, 9), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2021-06-24 2021-06-25 ... 2021-07-01
#   * plev     (plev) float64 1e+04 2e+04 2.5e+04 3e+04 ... 6e+04 7e+04 8.5e+04
# Dimensions without coordinates: member

# %%
# Compute the mean along the first dimension (axis=0)
mean_squared_diff = np.mean(squared_diff, axis=(-1,-2))

# %%
mean_squared_diff
# Out:
# <xarray.DataArray (member: 50)>
# dask.array<mean_agg-aggregate, shape=(50,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Dimensions without coordinates: member

# %%
squared_diff = (ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean[0,:,:] - ds_anomaly_era5_mean_T_L9_624701_mean) ** 2

# Step 3: Compute mean of the squared differences along the 'member' dimension
mean_squared_diff = np.mean(squared_diff

# %%
mean_squared_diff
# Out:
# <bound method DataArrayAggregations.mean of <xarray.DataArray (time: 8, plev: 9)>
# dask.array<pow, shape=(8, 9), dtype=float32, chunksize=(3, 9), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2021-06-24 2021-06-25 ... 2021-07-01
#   * plev     (plev) float64 1e+04 2e+04 2.5e+04 3e+04 ... 6e+04 7e+04 8.5e+04>

# %%
# Step 4: Compute the square root to get RMSE

# %%
rmse = np.sqrt(mean_squared_diff)

# %%
rmse.values
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 rmse.values
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/dataarray.py:732, in DataArray.values(self)
#     723 @property
#     724 def values(self) -> np.ndarray:
#     725     """
#     726     The array's data as a numpy.ndarray.
#     727
#    (...)
#     730     type does not support coercion like this (e.g. cupy).
#     731     """
# --> 732     return self.variable.values
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/variable.py:614, in Variable.values(self)
#     611 @property
#     612 def values(self):
#     613     """The variable's data as a numpy.ndarray"""
# --> 614     return _as_array_or_item(self._data)
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/variable.py:314, in _as_array_or_item(data)
# ...

# %%
rmse_30_fcnv2_ec = np.percentile(rmse.values,30)
rmse_70_fcnv2_ec = np.percentile(rmse.values,70)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 rmse_30_fcnv2_ec = np.percentile(rmse.values,30)
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/dataarray.py:732, in DataArray.values(self)
#     723 @property
#     724 def values(self) -> np.ndarray:
#     725     """
#     726     The array's data as a numpy.ndarray.
#     727
#    (...)
#     730     type does not support coercion like this (e.g. cupy).
#     731     """
# --> 732     return self.variable.values
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/variable.py:614, in Variable.values(self)
#     611 @property
#     612 def values(self):
#     613     """The variable's data as a numpy.ndarray"""
# --> 614     return _as_array_or_item(self._data)
#
# ...

# %%
# Since you're working with Dask arrays, compute() is needed to execute the computation
rmse_computed = rmse.compute()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 2
#       1 # Since you're working with Dask arrays, compute() is needed to execute the computation
# ----> 2 rmse_computed = rmse.compute()
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/dataarray.py:1101, in DataArray.compute(self, **kwargs)
#    1082 """Manually trigger loading of this array's data from disk or a
#    1083 remote source into memory and return a new array. The original is
#    1084 left unaltered.
#    (...)
#    1098 dask.compute
#    1099 """
#    1100 new = self.copy(deep=False)
# -> 1101 return new.load(**kwargs)
#
# File ~/anaconda3/envs/newenvi1/lib/python3.9/site-packages/xarray/core/dataarray.py:1075, in DataArray.load(self, **kwargs)
#    1057 def load(self: T_DataArray, **kwargs) -> T_DataArray:
# ...

# %%
# Compute the RMSE by taking the square root of the mean squared differences
rmse = np.sqrt(mean_squared_diff)

# %%
rmse_per_member_fcnv2_ec = np.sqrt(np.mean((ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean[0, :, :] - ds_anomaly_era5_mean_T_L9_624701_mean)**2))

# %%
rmse_per_member_fcnv2_ec
# Out:
# array([<xarray.DataArray ()>
#        dask.array<sqrt, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>,
#        <xarray.DataArray ()>
#        dask.array<sqrt, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>,
#        <xarray.DataArray ()>
#        dask.array<sqrt, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>,
#        <xarray.DataArray ()>
#        dask.array<sqrt, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>,
#        <xarray.DataArray ()>
#        dask.array<sqrt, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>],
#       dtype=object)

# %%
#calculate for the RMSE
rmse_per_member_fcnv2_ec = np.zeros((5),dtype=object)
for i in range(5):
    rmse_per_member_fcnv2_ec[i] = np.sqrt(np.mean((ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean[i, :, :] - ds_anomaly_era5_mean_T_L9_624701_mean)**2))

# %%
for i in range(5):
    rmse_per_member_fcnv2_ec[i].compute()

# %%
rmse_30_fcnv2_ec = np.percentile(rmse_per_member_fcnv2_ec,30)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 rmse_30_fcnv2_ec = np.percentile(rmse_per_member_fcnv2_ec,30)
#
# File /opt/bwhpc/common/jupyter/tensorflow/2023-10-10/lib/python3.9/site-packages/numpy/lib/function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File /opt/bwhpc/common/jupyter/tensorflow/2023-10-10/lib/python3.9/site-packages/numpy/lib/function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
# ...

# %%
rmse_30_fcnv2_ec
# Out:
# 7.393897533416748

# %%
rmse_70_fcnv2_ec = np.percentile(rmse_per_member_fcnv2_ec,70)

# %%
good_forecast_index_fcnv2_ec = np.where(rmse_per_member_fcnv2_ec < rmse_30_fcnv2_ec)
bad_forecast_index_fcnv2_ec = np.where(rmse_per_member_fcnv2_ec > rmse_70_fcnv2_ec)

# %%
good_forecast_fcnv2_ec = ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean[good_forecast_index_fcnv2_ec]
bad_forecast_fcnv2_ec = ds_anomaly_fcnv2_ec_ens_T_L9_0616_mean[bad_forecast_index_fcnv2_ec]

# %%
######################################################## plot session ##############################################################################################

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# %config InlineBackend.dpi = 300
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid

def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero
    
    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower ofset). Should be between
          0.0 and 1.0.
      midpoint : The new center of the colormap. Defaults to 
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax/(vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highets point in the colormap's range.
          Defaults to 1.0 (no upper ofset). Should be between
          0.0 and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }
      
    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False), 
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])
    
    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))
        
    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

# %%
from matplotlib.colors import LinearSegmentedColormap
my_gradient = LinearSegmentedColormap.from_list('my_gradient', (
    # Edit this gradient at https://eltos.github.io/gradient/#5:060E60-10:0012C7-20:1136C4-30:0B90EF-40:89B6E2-50:FFFFFF-50:FFFFFF-60:FFFFFF-70:FED4C4-80:FD9B82-90:BF5145-95:8D1F00
    (0.000, (0.024, 0.055, 0.376)),
    (0.050, (0.024, 0.055, 0.376)),
    (0.100, (0.000, 0.071, 0.780)),
    (0.200, (0.067, 0.212, 0.769)),
    (0.300, (0.043, 0.565, 0.937)),
    (0.400, (0.537, 0.714, 0.886)),
    (0.500, (1.000, 1.000, 1.000)),
    (0.500, (1.000, 1.000, 1.000)),
    (0.600, (1.000, 1.000, 1.000)),
    (0.700, (0.996, 0.831, 0.769)),
    (0.800, (0.992, 0.608, 0.510)),
    (0.900, (0.749, 0.318, 0.271)),
    (0.950, (0.553, 0.122, 0.000)),
    (1.000, (0.553, 0.122, 0.000))))

# %%
orig_cmap= my_gradient
shifted_cmap = shiftedColorMap(orig_cmap, midpoint=0.45, name='shifted_62')
# Out:
# /scratch/slurm_tmpdir/job_23167537/ipykernel_326534/2169532370.py:56: MatplotlibDeprecationWarning: The register_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps.register(name)`` instead.
#   plt.register_cmap(cmap=newcmap)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_temperature_anomaly(dataset,title,name):
    fig, ax = plt.subplots(figsize=(10, 6))

    # Extract times and levels from the dataset
    times = dataset.time  # datetime array
    levels = dataset.plev[:] / 100  # vertical levels array, converted to hPa

    # Prepare the grids for contour plot
    X, Y = np.meshgrid(mdates.date2num(times), levels)
    Z = dataset[:, :].T  # Transpose Z if necessary to match the dimensions of X and Y

    # Create the contour plot
    c = ax.contourf(X, Y, Z, cmap=shifted_cmap, levels=np.linspace(-18, 18, 19), extend='both')

    # Add a color bar
    fig.colorbar(c, ax=ax, label='Temperature Anomaly (K)')

    # Configure the x-axis with date formatting
    ax.xaxis.set_major_locator(mdates.DayLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

    ax.grid(True)

    ax.grid(color='gray', linestyle='--', linewidth=0.5)
    # Set labels and title
    ax.set_xlabel('Time (days)')
    ax.set_ylabel('Pressure (hPa)')
    ax.set_title(title)
    ax.invert_yaxis()

    # Rotate date labels for readability
    plt.xticks(rotation=45)
    plt.savefig(f'/home/kit/imk-tro/gj5173/vertical_temperature/{name}.png', bbox_inches='tight',dpi=200)
    plt.show()

# %%
plot_temperature_anomaly(ds_anomaly_era5_mean,'FCNV2_EC ensemble member7 Forecast Initialized on 16th June','anomaly_fcnv2_ec_m7_T_L9_0616_mean')

# %%
plot_temperature_anomaly(ds_anomaly_fcnv2_ec_cf_T_L9_0616_mean,'FCNV2_EC ensemble member7 Forecast Initialized on 16th June','anomaly_fcnv2_ec_m7_T_L9_0616_mean')
