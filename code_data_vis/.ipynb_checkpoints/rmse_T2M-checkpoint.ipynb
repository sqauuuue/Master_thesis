# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
#import os
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
import matplotlib.patches as patches
import os
import cartopy.mpl.ticker as cticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import re
import datetime
import pandas as pd
import matplotlib.dates as mdates
import dask.array as da
import seaborn as sns

import dask
import glob

# %%
############################################ load the dataset -fcnv2_ec ################################################################

# %%
# %store -r ds_fcnv2_ec_0616_ens
# %store -r ds_fcnv2_ec_0618_ens
# %store -r ds_fcnv2_ec_0620_ens
# %store -r ds_fcnv2_ec_0622_ens
# %store -r ds_fcnv2_ec_0623_ens

# %%
# %store -r ds_fcnv2_ec_0626_ens

# %%
#choose the forecast form 27.06 00UTC to 01.07 00UTC
ds_fcnv2_ec_0616_ens_t2m_2701 = ds_fcnv2_ec_0616_ens['2t'][:,43:60,0,260:39:-1,720:1201]
ds_fcnv2_ec_0618_ens_t2m_2701 = ds_fcnv2_ec_0618_ens['2t'][:,35:52,0,260:39:-1,720:1201]
ds_fcnv2_ec_0620_ens_t2m_2701 = ds_fcnv2_ec_0620_ens['2t'][:,27:44,0,260:39:-1,720:1201]
ds_fcnv2_ec_0622_ens_t2m_2701 = ds_fcnv2_ec_0622_ens['2t'][:,19:36,0,260:39:-1,720:1201]
ds_fcnv2_ec_0623_ens_t2m_2701 = ds_fcnv2_ec_0623_ens['2t'][:,15:32,0,260:39:-1,720:1201]
ds_fcnv2_ec_0626_ens_t2m_2701 = ds_fcnv2_ec_0626_ens['2t'][:,3:20,0,260:39:-1,720:1201]

# %%
#take the mean of time
ds_fcnv2_ec_0616_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0616_ens_t2m_2701,axis=1)
ds_fcnv2_ec_0618_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0618_ens_t2m_2701,axis=1)
ds_fcnv2_ec_0620_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0620_ens_t2m_2701,axis=1)
ds_fcnv2_ec_0622_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0622_ens_t2m_2701,axis=1)
ds_fcnv2_ec_0623_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0623_ens_t2m_2701,axis=1)
ds_fcnv2_ec_0626_ens_t2m_2701_mean = np.mean(ds_fcnv2_ec_0626_ens_t2m_2701,axis=1)

# %%
#choose the sbox
ds_fcnv2_ec_0616_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0616_ens_t2m_2701_mean[:,61:142,194:275]
ds_fcnv2_ec_0618_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0618_ens_t2m_2701_mean[:,61:142,194:275]
ds_fcnv2_ec_0620_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0620_ens_t2m_2701_mean[:,61:142,194:275]
ds_fcnv2_ec_0622_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0622_ens_t2m_2701_mean[:,61:142,194:275]
ds_fcnv2_ec_0623_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0623_ens_t2m_2701_mean[:,61:142,194:275]
ds_fcnv2_ec_0626_ens_t2m_2701_mean_sbox = ds_fcnv2_ec_0626_ens_t2m_2701_mean[:,61:142,194:275]

# %%
ds_fcnv2_ec_0616_ens_t2m_0629 = ds_fcnv2_ec_0616_ens['2t'][:,51,0,260:39:-1,720:1201]

# %%
ds_fcnv2_ec_0616_ens_tL9_landbox = ds_fcnv2_ec_0616_ens.t.isel(time = slice(31,60,4),plev=[1, 3, 4, 5, 6, 7, 8, 9, 10],lat =slice(164,123,-1),lon=slice(940,981))

# %%
ds_fcnv2_ec_0616_ens_t2m_0629 = ds_fcnv2_ec_0616_ens['2t'][:,51,0,260:39:-1,720:1201]
ds_fcnv2_ec_0618_ens_t2m_0629 = ds_fcnv2_ec_0618_ens['2t'][:,43,0,260:39:-1,720:1201]
ds_fcnv2_ec_0620_ens_t2m_0629 = ds_fcnv2_ec_0620_ens['2t'][:,35,0,260:39:-1,720:1201]
ds_fcnv2_ec_0622_ens_t2m_0629 = ds_fcnv2_ec_0622_ens['2t'][:,27,0,260:39:-1,720:1201]
ds_fcnv2_ec_0623_ens_t2m_0629 = ds_fcnv2_ec_0623_ens['2t'][:,23,0,260:39:-1,720:1201]

# %%
ds_fcnv2_ec_0626_ens_t2m_0629 = ds_fcnv2_ec_0626_ens['2t'][:,11,0,260:39:-1,720:1201]

# %%
#small box:61:141,194:274 (-131.5,40.25),20,20)
ds_fcnv2_ec_0616_ens_t2m_0629_sbox = ds_fcnv2_ec_0616_ens_t2m_0629[:,61:142,194:275]
ds_fcnv2_ec_0618_ens_t2m_0629_sbox = ds_fcnv2_ec_0618_ens_t2m_0629[:,61:142,194:275]
ds_fcnv2_ec_0620_ens_t2m_0629_sbox = ds_fcnv2_ec_0620_ens_t2m_0629[:,61:142,194:275]
ds_fcnv2_ec_0622_ens_t2m_0629_sbox = ds_fcnv2_ec_0622_ens_t2m_0629[:,61:142,194:275]
ds_fcnv2_ec_0623_ens_t2m_0629_sbox = ds_fcnv2_ec_0623_ens_t2m_0629[:,61:142,194:275]

# %%
ds_fcnv2_ec_0626_ens_t2m_0629_sbox = ds_fcnv2_ec_0626_ens_t2m_0629[:,61:142,194:275]

# %%
lat = np.linspace(25, 80, 221)
lon = np.linspace(-180, -60, 481)
lon_grid, lat_grid = np.meshgrid(lon, lat)


ds_era_t2m = ds_fcnv2_ec_0616_ens['2t'][0,0,0,260:39:-1,720:1201]



fig = plt.figure(figsize=(8,6))

ax = plt.axes(projection=ccrs.PlateCarree())
x, y = lon_grid, lat_grid  # Replace with the appropriate transformation method
leftlon, rightlon, lowerlat, upperlat = (-180,-60,25,80)#define map exten
ax.set_extent([leftlon, rightlon, lowerlat, upperlat], crs=ccrs.PlateCarree())
                  

# Add map 
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='w')


ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.set_xticks(np.arange(leftlon,rightlon+10,20), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(lowerlat,upperlat,20), crs=ccrs.PlateCarree())

lat_formatter = cticker.LatitudeFormatter()
lon_formatter = cticker.LongitudeFormatter()

ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Plot the contour map
contour1 = ax.contourf(x,y,ds_era_t2m,cmap='coolwarm',levels=20)
#mark the location of lytton
#red_point_lon = -121.50
#red_point_lat = 50.25
#ax.plot(red_point_lon, red_point_lat, 'r*', markersize=10)
# Add colorbar
#plt.colorbar()
cbar = plt.colorbar(contour1, ax=ax, label='Temperature/K',orientation='horizontal',shrink=0.5)


# Set plot title and labels
#plt.title('T2m_2021-06-29-00:00UTC_ERA5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#plt.savefig('T2m_2021-06-15_ERA5.png', bbox_inches='tight',dpi=100)

#656:2021.06.14 00UTC -06.29 00UTC

# Show the plot
#plt.show()

# %%
###################################### load era5 ##############################################################################

# %%
ds_era = xr.open_dataset('/lsdf/kit/imk-tro/projects/MOD/Gruppe_Knippertz/ey9908/tmp_Yangfan/data/era5/2021.h5')

# %%
#time from 00UTC 29.06 to 00UTC 01.07(from 708 to 724) 
ds_era5_2701_t2m=ds_era.fields[708:724,2,260:39:-1,720:1201]
ds_era5_2701_t2m_mean=np.mean(ds_era5_2701_t2m,axis=0)
ds_era5_2701_t2m_mean_sbox = ds_era5_2701_t2m_mean[61:142,194:275]

# %%
ds_era5_0629_t2m = ds_era.fields[716,2,260:39:-1,720:1201]

# %%
ds_era5_0629_t2m_sbox = ds_era5_0629_t2m[61:142,194:275]

# %%
lat = np.linspace(25, 80, 221)
lon = np.linspace(-180, -60, 481)
lon_grid, lat_grid = np.meshgrid(lon, lat)





fig = plt.figure(figsize=(8,6))

ax = plt.axes(projection=ccrs.PlateCarree())
x, y = lon_grid, lat_grid  # Replace with the appropriate transformation method
leftlon, rightlon, lowerlat, upperlat = (-180,-60,25,80)#define map exten
ax.set_extent([leftlon, rightlon, lowerlat, upperlat], crs=ccrs.PlateCarree())
                  

# Add map 
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='w')


ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.set_xticks(np.arange(leftlon,rightlon+10,20), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(lowerlat,upperlat,20), crs=ccrs.PlateCarree())

lat_formatter = cticker.LatitudeFormatter()
lon_formatter = cticker.LongitudeFormatter()

ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Plot the contour map
contour1 = ax.contourf(x,y,ds_era5_0629_t2m,cmap='coolwarm',levels=20)
#mark the location of lytton
#red_point_lon = -121.50
#red_point_lat = 50.25
#ax.plot(red_point_lon, red_point_lat, 'r*', markersize=10)
# Add colorbar
#plt.colorbar()
cbar = plt.colorbar(contour1, ax=ax, label='Temperature/K',orientation='horizontal',shrink=0.5)


# Set plot title and labels
#plt.title('T2m_2021-06-29-00:00UTC_ERA5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#plt.savefig('T2m_2021-06-15_ERA5.png', bbox_inches='tight',dpi=100)

#656:2021.06.14 00UTC -06.29 00UTC

# Show the plot
#plt.show()
# Out:
# Text(0, 0.5, 'Latitude')

# %%
################################ compute the RMSE between ERA5 and fcnv2_ec over teh s box##################################################

# %%
ds_era5_0629_t2m_sbox = ds_era5_0629_t2m_sbox.rename({'phony_dim_2': 'lat', 'phony_dim_3': 'lon'})

# %%
squared_diff_t2m_fcnv2_ec_0616 = (ds_fcnv2_ec_0616_ens_t2m_0629_sbox - ds_era5_0629_t2m_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0616 = np.mean(squared_diff_t2m_fcnv2_ec_0616, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0616 = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0616)

# %%
squared_diff_t2m_fcnv2_ec_0618 = (ds_fcnv2_ec_0618_ens_t2m_0629_sbox - ds_era5_0629_t2m_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0618 = np.mean(squared_diff_t2m_fcnv2_ec_0618, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0618 = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0618)

# %%
squared_diff_t2m_fcnv2_ec_0620 = (ds_fcnv2_ec_0620_ens_t2m_0629_sbox - ds_era5_0629_t2m_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0620 = np.mean(squared_diff_t2m_fcnv2_ec_0620, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0620 = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0620)

# %%
squared_diff_t2m_fcnv2_ec_0622 = (ds_fcnv2_ec_0622_ens_t2m_0629_sbox - ds_era5_0629_t2m_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0622 = np.mean(squared_diff_t2m_fcnv2_ec_0622, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0622 = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0622)

# %%
squared_diff_t2m_fcnv2_ec_0626 = (ds_fcnv2_ec_0626_ens_t2m_0629_sbox - ds_era5_0629_t2m_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0626 = np.mean(squared_diff_t2m_fcnv2_ec_0626, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0626 = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0626)

# %%
# %store rmse_t2m_fcnv2_ec_0616
# Out:
# Stored 'rmse_t2m_fcnv2_ec_0616' (ndarray)

# %%
rmse_t2m_fcnv2_ec_0618 = rmse_t2m_fcnv2_ec_0618.values

# %%
# %store rmse_t2m_fcnv2_ec_0618
# Out:
# Stored 'rmse_t2m_fcnv2_ec_0618' (ndarray)

# %%
rmse_t2m_fcnv2_ec_0620 = rmse_t2m_fcnv2_ec_0620.values

# %%
# %store rmse_t2m_fcnv2_ec_0620
# Out:
# Stored 'rmse_t2m_fcnv2_ec_0620' (ndarray)

# %%
rmse_t2m_fcnv2_ec_0622 = rmse_t2m_fcnv2_ec_0622.values

# %%
# %store -r rmse_t2m_fcnv2_ec_0622

# %%
rmse_t2m_fcnv2_ec_0626 = rmse_t2m_fcnv2_ec_0626.values

# %%
# %store rmse_t2m_fcnv2_ec_0626
# Out:
# Stored 'rmse_t2m_fcnv2_ec_0626' (ndarray)

# %%
#choose the 70 and 30 quantile for RMSE
rmse_30_t2m_fcnv2_ec_0616 = np.percentile(rmse_t2m_fcnv2_ec_0616,30)
rmse_70_t2m_fcnv2_ec_0616 = np.percentile(rmse_t2m_fcnv2_ec_0616,70)

rmse_30_t2m_fcnv2_ec_0618 = np.percentile(rmse_t2m_fcnv2_ec_0618,30)
rmse_70_t2m_fcnv2_ec_0618 = np.percentile(rmse_t2m_fcnv2_ec_0618,70)

rmse_30_t2m_fcnv2_ec_0620 = np.percentile(rmse_t2m_fcnv2_ec_0620,30)
rmse_70_t2m_fcnv2_ec_0620 = np.percentile(rmse_t2m_fcnv2_ec_0620,70)


rmse_30_t2m_fcnv2_ec_0622 = np.percentile(rmse_t2m_fcnv2_ec_0622,30)
rmse_70_t2m_fcnv2_ec_0622 = np.percentile(rmse_t2m_fcnv2_ec_0622,70)

# %%
rmse_30_t2m_fcnv2_ec_0626 = np.percentile(rmse_t2m_fcnv2_ec_0626,30)
rmse_70_t2m_fcnv2_ec_0626 = np.percentile(rmse_t2m_fcnv2_ec_0626,70)

# %%
#choose the memebr index based on the rmse(70% and 30%)
good_forecast_index_fcnv2_ec_0616_t2m = np.where(rmse_t2m_fcnv2_ec_0616 < rmse_30_t2m_fcnv2_ec_0616 )
bad_forecast_index_fcnv2_ec_0616_t2m = np.where(rmse_t2m_fcnv2_ec_0616 > rmse_70_t2m_fcnv2_ec_0616)
good_forecast_index_fcnv2_ec_0618_t2m = np.where(rmse_t2m_fcnv2_ec_0618 < rmse_30_t2m_fcnv2_ec_0618 )
bad_forecast_index_fcnv2_ec_0618_t2m = np.where(rmse_t2m_fcnv2_ec_0618 > rmse_70_t2m_fcnv2_ec_0618)
good_forecast_index_fcnv2_ec_0620_t2m = np.where(rmse_t2m_fcnv2_ec_0620 < rmse_30_t2m_fcnv2_ec_0620 )
bad_forecast_index_fcnv2_ec_0620_t2m = np.where(rmse_t2m_fcnv2_ec_0620 > rmse_70_t2m_fcnv2_ec_0620)
good_forecast_index_fcnv2_ec_0622_t2m = np.where(rmse_t2m_fcnv2_ec_0622 < rmse_30_t2m_fcnv2_ec_0622)
bad_forecast_index_fcnv2_ec_0622_t2m = np.where(rmse_t2m_fcnv2_ec_0622 > rmse_70_t2m_fcnv2_ec_0622)

# %%
good_forecast_index_fcnv2_ec_0626_t2m = np.where(rmse_t2m_fcnv2_ec_0626 < rmse_30_t2m_fcnv2_ec_0626)
bad_forecast_index_fcnv2_ec_0626_t2m = np.where(rmse_t2m_fcnv2_ec_0626 > rmse_70_t2m_fcnv2_ec_0626)

# %%
# %store good_forecast_index_fcnv2_ec_0616_t2m
# %store bad_forecast_index_fcnv2_ec_0616_t2m
# %store good_forecast_index_fcnv2_ec_0618_t2m
# %store bad_forecast_index_fcnv2_ec_0618_t2m
# %store good_forecast_index_fcnv2_ec_0620_t2m
# %store bad_forecast_index_fcnv2_ec_0620_t2m
# %store good_forecast_index_fcnv2_ec_0622_t2m
# %store bad_forecast_index_fcnv2_ec_0622_t2m
# Out:
# Stored 'good_forecast_index_fcnv2_ec_0616_t2m' (tuple)
# Stored 'bad_forecast_index_fcnv2_ec_0616_t2m' (tuple)
# Stored 'good_forecast_index_fcnv2_ec_0618_t2m' (tuple)
# Stored 'bad_forecast_index_fcnv2_ec_0618_t2m' (tuple)
# Stored 'good_forecast_index_fcnv2_ec_0620_t2m' (tuple)
# Stored 'bad_forecast_index_fcnv2_ec_0620_t2m' (tuple)
# Stored 'good_forecast_index_fcnv2_ec_0622_t2m' (tuple)
# Stored 'bad_forecast_index_fcnv2_ec_0622_t2m' (tuple)

# %%
# %store good_forecast_index_fcnv2_ec_0626_t2m
# %store bad_forecast_index_fcnv2_ec_0626_t2m
# Out:
# Stored 'good_forecast_index_fcnv2_ec_0626_t2m' (tuple)
# Stored 'bad_forecast_index_fcnv2_ec_0626_t2m' (tuple)

# %%
good_forecast_index_fcnv2_ec_0616_t2m
# Out:
# (array([ 1,  2,  9, 10, 17, 22, 23, 24, 29, 30, 33, 37, 38, 39, 42]),)

# %%
############################################################### compute the RMSE based on the froecast from 27.JUEN 00utc to 01.07 00UTC ####################################

# %%
ds_era5_2701_t2m_mean_sbox = ds_era5_2701_t2m_mean_sbox.rename({'phony_dim_2': 'lat', 'phony_dim_3': 'lon'})

# %%
squared_diff_t2m_fcnv2_ec_0616_range = (ds_fcnv2_ec_0616_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0616_range = np.mean(squared_diff_t2m_fcnv2_ec_0616_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0616_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0616_range)

# %%
squared_diff_t2m_fcnv2_ec_0618_range = (ds_fcnv2_ec_0618_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0618_range = np.mean(squared_diff_t2m_fcnv2_ec_0618_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0618_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0618_range)

# %%
squared_diff_t2m_fcnv2_ec_0620_range = (ds_fcnv2_ec_0620_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0620_range = np.mean(squared_diff_t2m_fcnv2_ec_0620_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0620_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0620_range)

# %%
squared_diff_t2m_fcnv2_ec_0622_range = (ds_fcnv2_ec_0622_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0622_range = np.mean(squared_diff_t2m_fcnv2_ec_0622_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0622_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0622_range)

# %%
squared_diff_t2m_fcnv2_ec_0623_range = (ds_fcnv2_ec_0623_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0623_range = np.mean(squared_diff_t2m_fcnv2_ec_0623_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0623_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0623_range)

# %%
squared_diff_t2m_fcnv2_ec_0626_range = (ds_fcnv2_ec_0626_ens_t2m_2701_mean_sbox - ds_era5_2701_t2m_mean_sbox) ** 2
mean_squared_diff_t2m_fcnv2_ec_0626_range = np.mean(squared_diff_t2m_fcnv2_ec_0626_range, axis=(-1,-2))
rmse_t2m_fcnv2_ec_0626_range = np.sqrt(mean_squared_diff_t2m_fcnv2_ec_0626_range)

# %%
rmse_t2m_fcnv2_ec_0616_range = rmse_t2m_fcnv2_ec_0616_range.values
# Out:
# <xarray.DataArray (member: 50)>
# dask.array<sqrt, shape=(50,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     height_3  float64 2.0
# Dimensions without coordinates: member

# %%
######################################################## select of good forecast and bad forecast ############################

# %%
a = np.mean(ds_fcnv2_ec_0616_ens_t2m_0629[good_forecast_index_fcnv2_ec_0616],axis=0)

# %%
b = np.mean(ds_fcnv2_ec_0616_ens_t2m_0629[bad_forecast_index_fcnv2_ec_0616],axis=0)

# %%
lat = np.linspace(25, 80, 221)
lon = np.linspace(-180, -60, 481)
lon_grid, lat_grid = np.meshgrid(lon, lat)





fig = plt.figure(figsize=(8,6))

ax = plt.axes(projection=ccrs.PlateCarree())
x, y = lon_grid, lat_grid  # Replace with the appropriate transformation method
leftlon, rightlon, lowerlat, upperlat = (-180,-60,25,80)#define map exten
ax.set_extent([leftlon, rightlon, lowerlat, upperlat], crs=ccrs.PlateCarree())
                  

# Add map 
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='w')


ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.set_xticks(np.arange(leftlon,rightlon+10,20), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(lowerlat,upperlat,20), crs=ccrs.PlateCarree())

lat_formatter = cticker.LatitudeFormatter()
lon_formatter = cticker.LongitudeFormatter()

ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Plot the contour map
contour1 = ax.contourf(x,y,a,cmap='coolwarm',levels=20)
#mark the location of lytton
#red_point_lon = -121.50
#red_point_lat = 50.25
#ax.plot(red_point_lon, red_point_lat, 'r*', markersize=10)
# Add colorbar
#plt.colorbar()
cbar = plt.colorbar(contour1, ax=ax, label='Temperature/K',orientation='horizontal',shrink=0.5)


# Set plot title and labels
#plt.title('T2m_2021-06-29-00:00UTC_ERA5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#plt.savefig('T2m_2021-06-15_ERA5.png', bbox_inches='tight',dpi=100)

#656:2021.06.14 00UTC -06.29 00UTC

# Show the plot
#plt.show()
# Out:
# Text(0, 0.5, 'Latitude')

# %%
lat = np.linspace(25, 80, 221)
lon = np.linspace(-180, -60, 481)
lon_grid, lat_grid = np.meshgrid(lon, lat)





fig = plt.figure(figsize=(8,6))

ax = plt.axes(projection=ccrs.PlateCarree())
x, y = lon_grid, lat_grid  # Replace with the appropriate transformation method
leftlon, rightlon, lowerlat, upperlat = (-180,-60,25,80)#define map exten
ax.set_extent([leftlon, rightlon, lowerlat, upperlat], crs=ccrs.PlateCarree())
                  

# Add map 
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.OCEAN, facecolor='w')


ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.set_xticks(np.arange(leftlon,rightlon+10,20), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(lowerlat,upperlat,20), crs=ccrs.PlateCarree())

lat_formatter = cticker.LatitudeFormatter()
lon_formatter = cticker.LongitudeFormatter()

ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Plot the contour map
contour1 = ax.contourf(x,y,b,cmap='coolwarm',levels=20)
#mark the location of lytton
#red_point_lon = -121.50
#red_point_lat = 50.25
#ax.plot(red_point_lon, red_point_lat, 'r*', markersize=10)
# Add colorbar
#plt.colorbar()
cbar = plt.colorbar(contour1, ax=ax, label='Temperature/K',orientation='horizontal',shrink=0.5)


# Set plot title and labels
#plt.title('T2m_2021-06-29-00:00UTC_ERA5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#plt.savefig('T2m_2021-06-15_ERA5.png', bbox_inches='tight',dpi=100)

#656:2021.06.14 00UTC -06.29 00UTC

# Show the plot
#plt.show()
# Out:
# Text(0, 0.5, 'Latitude')

# %%
####################################### the ifs_ens #############################################################################
