# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
#import os
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
import matplotlib.patches as patches
import os
import cartopy.mpl.ticker as cticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import pandas as pd
import matplotlib.dates as mdates
import re
import datetime

# %%
# Assuming you have longitude and latitude arrays with 0.25-degree resolution
lat = np.linspace(25, 80, 220)
lon = np.linspace(-180, -60, 480)

# %%
# Specify the desired longitude and latitude
desired_lon = -121.50
desired_lat = 50.25

# Calculate the indices for the desired grid point
lon_index = int(round((desired_lon - lon[0]) / 0.25))
lat_index = int(round((lat[0]-desired_lat ) / 0.25))

# %%
lon_index
# Out:
# 234

# %%
lat_index
# Access the grid value at the specified indices
#selected_value = grid[lat_index, lon_index]
# Out:
# -101

# %%
ds_era = xr.open_dataset('/pfs/work7/workspace/scratch/ab6801-fourcastnet/era5/2021.h5')
lat = ds_era['phony_dim_2']
lat

lytton_t2m_0h = ds_era.fields[656:737:4,2,260:40:-1,720:1200]
lytton_t2m_1_0h = lytton_t2m_0h[:,101,234]

lytton_t2m_6h = ds_era.fields[657:738:4,2,260:40:-1,720:1200]
lytton_t2m_1_6h = lytton_t2m_6h[:,101,234]

lytton_t2m_12h = ds_era.fields[658:739:4,2,260:40:-1,720:1200]
lytton_t2m_1_12h = lytton_t2m_12h[:,101,234]

lytton_t2m_18h = ds_era.fields[659:740:4,2,260:40:-1,720:1200]
lytton_t2m_1_18h = lytton_t2m_18h[:,101,234]

lytton_t2m_24h = ds_era.fields[660:741:4,2,260:40:-1,720:1200]
lytton_t2m_1_24h = lytton_t2m_24h[:,101,234]

lytton_t2m_30h = ds_era.fields[661:742:4,2,260:40:-1,720:1200]
lytton_t2m_1_30h = lytton_t2m_30h[:,101,234]

lytton_t2m_36h = ds_era.fields[662:743:4,2,260:40:-1,720:1200]
lytton_t2m_1_36h = lytton_t2m_36h[:,101,234]

lytton_t2m_42h = ds_era.fields[663:744:4,2,260:40:-1,720:1200]
lytton_t2m_1_42h = lytton_t2m_42h[:,101,234]

lytton_t2m_48h = ds_era.fields[664:745:4,2,260:40:-1,720:1200]
lytton_t2m_1_48h = lytton_t2m_48h[:,101,234]

lytton_t2m_54h = ds_era.fields[665:746:4,2,260:40:-1,720:1200]
lytton_t2m_1_54h = lytton_t2m_54h[:,101,234]

lytton_t2m_60h = ds_era.fields[666:747:4,2,260:40:-1,720:1200]
lytton_t2m_1_60h = lytton_t2m_60h[:,101,234]

lytton_t2m_66h = ds_era.fields[667:748:4,2,260:40:-1,720:1200]
lytton_t2m_1_66h = lytton_t2m_66h[:,101,234]

lytton_t2m_72h = ds_era.fields[668:749:4,2,260:40:-1,720:1200]
lytton_t2m_1_72h = lytton_t2m_72h[:,101,234]

lytton_t2m_78h = ds_era.fields[669:750:4,2,260:40:-1,720:1200]
lytton_t2m_1_78h = lytton_t2m_78h[:,101,234]

lytton_t2m_84h = ds_era.fields[670:751:4,2,260:40:-1,720:1200]
lytton_t2m_1_84h = lytton_t2m_84h[:,101,234]

lytton_t2m_90h = ds_era.fields[671:752:4,2,260:40:-1,720:1200]
lytton_t2m_1_90h = lytton_t2m_90h[:,101,234]

lytton_t2m_96h = ds_era.fields[672:753:4,2,260:40:-1,720:1200]
lytton_t2m_1_96h = lytton_t2m_96h[:,101,234]

lytton_t2m_102h = ds_era.fields[673:754:4,2,260:40:-1,720:1200]
lytton_t2m_1_102h = lytton_t2m_102h[:,101,234]

lytton_t2m_108h = ds_era.fields[674:755:4,2,260:40:-1,720:1200]
lytton_t2m_1_108h = lytton_t2m_108h[:,101,234]

lytton_t2m_114h = ds_era.fields[675:756:4,2,260:40:-1,720:1200]
lytton_t2m_1_114h = lytton_t2m_114h[:,101,234]

lytton_t2m_120h = ds_era.fields[676:757:4,2,260:40:-1,720:1200]
lytton_t2m_1_120h = lytton_t2m_120h[:,101,234]

lytton_t2m_126h = ds_era.fields[677:758:4,2,260:40:-1,720:1200]
lytton_t2m_1_126h = lytton_t2m_126h[:,101,234]

lytton_t2m_132h = ds_era.fields[678:759:4,2,260:40:-1,720:1200]
lytton_t2m_1_132h = lytton_t2m_132h[:,101,234]

lytton_t2m_138h = ds_era.fields[679:760:4,2,260:40:-1,720:1200]
lytton_t2m_1_138h = lytton_t2m_138h[:,101,234]

lytton_t2m_144h = ds_era.fields[680:761:4,2,260:40:-1,720:1200]
lytton_t2m_1_144h = lytton_t2m_144h[:,101,234]

lytton_t2m_150h = ds_era.fields[681:762:4,2,260:40:-1,720:1200]
lytton_t2m_1_150h = lytton_t2m_150h[:,101,234]

lytton_t2m_156h = ds_era.fields[682:763:4,2,260:40:-1,720:1200]
lytton_t2m_1_156h = lytton_t2m_156h[:,101,234]

lytton_t2m_162h = ds_era.fields[683:764:4,2,260:40:-1,720:1200]
lytton_t2m_1_162h = lytton_t2m_162h[:,101,234]

lytton_t2m_168h = ds_era.fields[684:765:4,2,260:40:-1,720:1200]
lytton_t2m_1_168h = lytton_t2m_168h[:,101,234]

lytton_t2m_174h = ds_era.fields[685:766:4,2,260:40:-1,720:1200]
lytton_t2m_1_174h = lytton_t2m_174h[:,101,234]

lytton_t2m_180h = ds_era.fields[686:767:4,2,260:40:-1,720:1200]
lytton_t2m_1_180h = lytton_t2m_180h[:,101,234]

lytton_t2m_186h = ds_era.fields[687:768:4,2,260:40:-1,720:1200]
lytton_t2m_1_186h = lytton_t2m_186h[:,101,234]

lytton_t2m_192h = ds_era.fields[688:769:4,2,260:40:-1,720:1200]
lytton_t2m_1_192h = lytton_t2m_192h[:,101,234]

lytton_t2m_198h = ds_era.fields[689:770:4,2,260:40:-1,720:1200]
lytton_t2m_1_198h = lytton_t2m_198h[:,101,234]

lytton_t2m_204h = ds_era.fields[690:771:4,2,260:40:-1,720:1200]
lytton_t2m_1_204h = lytton_t2m_024h[:,101,234]

lytton_t2m_210h = ds_era.fields[691:772:4,2,260:40:-1,720:1200]
lytton_t2m_1_210h = lytton_t2m_210h[:,101,234]

lytton_t2m_216h = ds_era.fields[692:773:4,2,260:40:-1,720:1200]
lytton_t2m_1_216h = lytton_t2m_216h[:,101,234]

# %%
#lytton_t2m_1.values

# %%
time_series_data_0h = lytton_t2m_1_0h.values.ravel()
time_series_data_6h = lytton_t2m_1_6h.values.ravel()
time_series_data_12h = lytton_t2m_1_12h.values.ravel()
time_series_data_18h = lytton_t2m_1_18h.values.ravel()
time_series_data_24h = lytton_t2m_1_24h.values.ravel()
time_series_data_30h = lytton_t2m_1_30h.values.ravel()
time_series_data_36h = lytton_t2m_1_36h.values.ravel()
time_series_data_42h = lytton_t2m_1_42h.values.ravel()
time_series_data_48h = lytton_t2m_1_48h.values.ravel()
time_series_data_54h = lytton_t2m_1_54h.values.ravel()
time_series_data_60h = lytton_t2m_1_60h.values.ravel()
time_series_data_66h = lytton_t2m_1_66h.values.ravel()
time_series_data_72h = lytton_t2m_1_72h.values.ravel()
time_series_data_78h = lytton_t2m_1_78h.values.ravel()
time_series_data_84h = lytton_t2m_1_84h.values.ravel()
time_series_data_90h = lytton_t2m_1_90h.values.ravel()
time_series_data_96h = lytton_t2m_1_96h.values.ravel()
time_series_data_102h = lytton_t2m_1_102h.values.ravel()
time_series_data_108h = lytton_t2m_1_108h.values.ravel()
time_series_data_114h = lytton_t2m_1_114h.values.ravel()
time_series_data_120h = lytton_t2m_1_120h.values.ravel()
time_series_data_126h = lytton_t2m_1_126h.values.ravel()
time_series_data_132h = lytton_t2m_1_132h.values.ravel()

time_series_data_138h = lytton_t2m_1_138h.values.ravel()
time_series_data_144h = lytton_t2m_1_144h.values.ravel()
time_series_data_150h = lytton_t2m_1_150h.values.ravel()
time_series_data_156h = lytton_t2m_1_156h.values.ravel()
time_series_data_162h = lytton_t2m_1_162h.values.ravel()
time_series_data_168h = lytton_t2m_1_168h.values.ravel()

time_series_data_174h = lytton_t2m_1_174h.values.ravel()
time_series_data_180h = lytton_t2m_1_180h.values.ravel()
time_series_data_186h = lytton_t2m_1_186h.values.ravel()
time_series_data_192h = lytton_t2m_1_192h.values.ravel()
time_series_data_198h = lytton_t2m_1_198h.values.ravel()
time_series_data_204h = lytton_t2m_1_204h.values.ravel()

time_series_data_210h = lytton_t2m_1_210h.values.ravel()
time_series_data_216h = lytton_t2m_1_216h.values.ravel()
#start_date = '2021-01-01'

# Create a pandas Series with the time series data
#time_series = pd.Series(time_series_data)


#times = pd.to_datetime(ds_era['phony_dim_0'][656:736].values, origin=start_date)


start_date = '2021-06-14'
end_date = '2021-07-04'
time_interval = '1D'

time_range = pd.date_range(start=start_date, end=end_date, freq=time_interval)

# %%
lat_fcn = np.arange(80, 25, -0.25)
lon_fcn = np.arange(-180, -60, 0.25)
lon_index_fcn = int(round((desired_lon - lon_fcn[0]) / 0.25))
lat_index_fcn = int(round((lat_fcn[0]-desired_lat ) / 0.25))
lon_index_fcn
# Out:
# 234

# %%
lat_index_fcn
# Out:
# 119

# %%
ds_fcn_21 = xr.open_dataset('/pfs/work7/workspace/scratch/ab6801-fourcastnet/fourcastnet/2021_dt_list_ens_backtransformed.nc',engine = 'netcdf4')
ds_fcn_21
time_series_data_1 =ds_fcn_21.forecast[:,0,0,2,119,234]
#phony_dim_4-lat phony_dim_5-lon phony_dim_0-time phony_dim_2-leadtime phony_dim_1-pertubated members phony_dim_3:variables

#0h
start_date_1 = '2021-06-14'
end_date_1 = '2021-07-04'
time_interval_1 = '1D'
time_range_1 = pd.date_range(start=start_date_1, end=end_date_1, freq=time_interval_1)
time_range_1
# Out:
# DatetimeIndex(['2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17',
#                '2021-06-18', '2021-06-19', '2021-06-20', '2021-06-21',
#                '2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25',
#                '2021-06-26', '2021-06-27', '2021-06-28', '2021-06-29',
#                '2021-06-30', '2021-07-01', '2021-07-02', '2021-07-03',
#                '2021-07-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
#6h
start_date_2 = '2021-06-14 06:00:00'
end_date_2 = '2021-07-04 06:00:00'
time_interval_2 = '1D'
time_range_2 = pd.date_range(start=start_date_2, end=end_date_2, freq=time_interval_2)
#time_range_2

# %%
#12h
start_date_3 = '2021-06-14 12:00:00'
end_date_3 = '2021-07-04 12:00:00'
time_interval_3 = '1D'
time_range_3 = pd.date_range(start=start_date_3, end=end_date_3, freq=time_interval_3)

# %%
#18h
start_date_4 = '2021-06-14 18:00:00'
end_date_4 = '2021-07-04 18:00:00'
time_interval_4 = '1D'
time_range_4 = pd.date_range(start=start_date_4, end=end_date_4, freq=time_interval_4)

# %%
#24h
start_date_5 = '2021-06-15 00:00:00'
end_date_5 = '2021-07-05 00:00:00'
time_interval_5 = '1D'
time_range_5 = pd.date_range(start=start_date_5, end=end_date_5, freq=time_interval_5)

# %%
#30h
start_date_6 = '2021-06-15 06:00:00'
end_date_6 = '2021-07-05 06:00:00'
time_interval_6 = '1D'
time_range_6 = pd.date_range(start=start_date_6, end=end_date_6, freq=time_interval_6)

# %%
#36h
start_date_7 = '2021-06-15 12:00:00'
end_date_7 = '2021-07-05 12:00:00'
time_interval_7 = '1D'
time_range_7 = pd.date_range(start=start_date_7, end=end_date_7, freq=time_interval_7)

# %%
#42h
start_date_8 = '2021-06-15 18:00:00'
end_date_8 = '2021-07-05 18:00:00'
time_interval_8 = '1D'
time_range_8 = pd.date_range(start=start_date_8, end=end_date_8, freq=time_interval_8)

# %%
#48h
start_date_9 = '2021-06-16 00:00:00'
end_date_9 = '2021-07-06 00:00:00'
time_interval_9 = '1D'
time_range_9 = pd.date_range(start=start_date_9, end=end_date_9, freq=time_interval_9)

# %%
#54h
start_date_10 = '2021-06-16 06:00:00'
end_date_10 = '2021-07-06 06:00:00'
time_interval_10 = '1D'
time_range_10 = pd.date_range(start=start_date_10, end=end_date_10, freq=time_interval_10)

# %%
#60h
start_date_11 = '2021-06-16 12:00:00'
end_date_11 = '2021-07-06 12:00:00'
time_interval_11 = '1D'
time_range_11 = pd.date_range(start=start_date_11, end=end_date_11, freq=time_interval_11)

# %%
#66h
start_date_12 = '2021-06-16 18:00:00'
end_date_12 = '2021-07-06 18:00:00'
time_interval_12 = '1D'
time_range_12 = pd.date_range(start=start_date_12, end=end_date_12, freq=time_interval_12)

# %%
#72h
start_date_13 = '2021-06-17 00:00:00'
end_date_13 = '2021-07-07 00:00:00'
time_interval_13 = '1D'
time_range_13 = pd.date_range(start=start_date_13, end=end_date_13, freq=time_interval_13)

# %%
#78h
start_date_14 = '2021-06-17 06:00:00'
end_date_14 = '2021-07-07 06:00:00'
time_interval_14 = '1D'
time_range_14 = pd.date_range(start=start_date_14, end=end_date_14, freq=time_interval_14)

# %%
#84h
start_date_15 = '2021-06-17 12:00:00'
end_date_15 = '2021-07-07 12:00:00'
time_interval_15 = '1D'
time_range_15 = pd.date_range(start=start_date_15, end=end_date_15, freq=time_interval_15)

# %%
#90h
start_date_16 = '2021-06-17 18:00:00'
end_date_16 = '2021-07-07 18:00:00'
time_interval_16 = '1D'
time_range_16 = pd.date_range(start=start_date_16, end=end_date_16, freq=time_interval_16)

# %%
#96h
start_date_17 = '2021-06-18 00:00:00'
end_date_17 = '2021-07-08 00:00:00'
time_interval_17 = '1D'
time_range_17 = pd.date_range(start=start_date_17, end=end_date_17, freq=time_interval_17)

# %%
#102h
start_date_18 = '2021-06-18 06:00:00'
end_date_18 = '2021-07-08 06:00:00'
time_interval_18 = '1D'
time_range_18 = pd.date_range(start=start_date_18, end=end_date_18, freq=time_interval_18)

# %%
#108h
start_date_19 = '2021-06-18 12:00:00'
end_date_19 = '2021-07-08 12:00:00'
time_interval_19 = '1D'
time_range_19 = pd.date_range(start=start_date_19, end=end_date_19, freq=time_interval_19)

# %%
#114h
start_date_20 = '2021-06-18 18:00:00'
end_date_20 = '2021-07-08 18:00:00'
time_interval_20 = '1D'
time_range_20 = pd.date_range(start=start_date_20, end=end_date_20, freq=time_interval_20)

# %%
#120h
start_date_21 = '2021-06-19 00:00:00'
end_date_21 = '2021-07-09 00:00:00'
time_interval_21 = '1D'
time_range_21 = pd.date_range(start=start_date_21, end=end_date_21, freq=time_interval_21)

# %%
#126h
start_date_22 = '2021-06-19 06:00:00'
end_date_22 = '2021-07-09 06:00:00'
time_interval_22 = '1D'
time_range_22 = pd.date_range(start=start_date_22, end=end_date_22, freq=time_interval_22)

# %%
#132h
start_date_23 = '2021-06-19 12:00:00'
end_date_23 = '2021-07-09 12:00:00'
time_interval_23 = '1D'
time_range_23 = pd.date_range(start=start_date_23, end=end_date_23, freq=time_interval_23)

# %%
#138h
start_date_24 = '2021-06-19 18:00:00'
end_date_24 = '2021-07-09 18:00:00'
time_interval_24 = '1D'
time_range_24 = pd.date_range(start=start_date_24, end=end_date_24, freq=time_interval_24)

# %%
#144h
start_date_25 = '2021-06-20 00:00:00'
end_date_25 = '2021-07-10 00:00:00'
time_interval_25 = '1D'
time_range_25 = pd.date_range(start=start_date_25, end=end_date_25, freq=time_interval_25)

# %%
#150h
start_date_26 = '2021-06-20 06:00:00'
end_date_26 = '2021-07-10 06:00:00'
time_interval_26 = '1D'
time_range_26 = pd.date_range(start=start_date_26, end=end_date_26, freq=time_interval_26)

# %%
#156h
start_date_27 = '2021-06-20 12:00:00'
end_date_27 = '2021-07-10 12:00:00'
time_interval_27 = '1D'
time_range_27 = pd.date_range(start=start_date_27, end=end_date_27, freq=time_interval_27)

# %%
#162h
start_date_28 = '2021-06-20 18:00:00'
end_date_28 = '2021-07-10 18:00:00'
time_interval_28 = '1D'
time_range_28 = pd.date_range(start=start_date_28, end=end_date_28, freq=time_interval_28)

# %%
#168h
start_date_29 = '2021-06-21 00:00:00'
end_date_29 = '2021-07-10 00:00:00'
time_interval_29 = '1D'
time_range_29 = pd.date_range(start=start_date_29, end=end_date_29, freq=time_interval_29)

# %%
#174h
start_date_30 = '2021-06-22 06:00:00'
end_date_30 = '2021-07-11 06:00:00'
time_interval_30 = '1D'
time_range_30 = pd.date_range(start=start_date_30, end=end_date_30, freq=time_interval_30)

# %%
#180h
start_date_31 = '2021-06-22 12:00:00'
end_date_31 = '2021-07-11 12:00:00'
time_interval_31 = '1D'
time_range_31 = pd.date_range(start=start_date_31, end=end_date_31, freq=time_interval_31)

# %%
#186h
start_date_32 = '2021-06-22 18:00:00'
end_date_32 = '2021-07-11 18:00:00'
time_interval_32 = '1D'
time_range_32 = pd.date_range(start=start_date_32, end=end_date_32, freq=time_interval_32)

# %%
#192h
start_date_33 = '2021-06-23 00:00:00'
end_date_33 = '2021-07-12 00:00:00'
time_interval_33 = '1D'
time_range_33 = pd.date_range(start=start_date_33, end=end_date_33, freq=time_interval_33)

# %%
#198h
start_date_34 = '2021-06-23 06:00:00'
end_date_34 = '2021-07-12 06:00:00'
time_interval_34 = '1D'
time_range_34 = pd.date_range(start=start_date_34, end=end_date_34, freq=time_interval_34)

# %%
#204h
start_date_35 = '2021-06-23 12:00:00'
end_date_35 = '2021-07-12 12:00:00'
time_interval_35 = '1D'
time_range_35 = pd.date_range(start=start_date_35, end=end_date_35, freq=time_interval_35)

# %%
#210h
start_date_36 = '2021-06-23 18:00:00'
end_date_36 = '2021-07-12 18:00:00'
time_interval_36 = '1D'
time_range_36 = pd.date_range(start=start_date_36, end=end_date_36, freq=time_interval_36)

# %%
#216h
start_date_37 = '2021-06-24 00:00:00'
end_date_37 = '2021-07-13 00:00:00'
time_interval_37 = '1D'
time_range_37 = pd.date_range(start=start_date_37, end=end_date_37, freq=time_interval_37)

# %%
ds_fcn_21.forecast[:,0,0,2,119,234].values
# Out:
# array([287.05575559, 286.65728786, 285.65609745, 291.03851295,
#        293.43136633, 292.0917665 , 289.89715541, 295.70208802,
#        298.5174253 , 297.87066658, 294.6328122 , 294.64282245,
#        301.4789743 , 305.77008096, 307.37200963, 308.2991026 ,
#        309.98510767, 303.94400134, 300.524628  , 298.35836844,
#        297.1946101 ])

# %%
fig2 = plt.figure(figsize=(12,3))
plt.plot(time_range_1, time_series_data_1)
# Set the plot title and labels
plt.title('T2m_Fourcastnet(ERA5)_Lytton',loc='left')
plt.title('Lead Time = +0h',loc='right')
plt.xlabel('Forecast Initialization')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_1, time_range_1, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot
plt.show()

# %%
#ECMWF
ds_ecmwf = xr.open_dataset('/lsdf/kit/imk-tro/projects/MOD/Gruppe_Grams/nk2448/2023_FourCastNet/Yangfan/validation/fc_cf_20210615_00_sfc.nc')
ds_ecmwf
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 481, latitude: 221, time: 57)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... -60.5 -60.25 -60.0
#   * latitude   (latitude) float32 80.0 79.75 79.5 79.25 ... 25.5 25.25 25.0
#   * time       (time) datetime64[ns] 2021-06-15 ... 2021-06-29
# Data variables:
#     sp         (time, latitude, longitude) float32 ...
#     tcwv       (time, latitude, longitude) float32 ...
#     msl        (time, latitude, longitude) float32 ...
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
#     t2m        (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-06-08 15:19:10 GMT by grib_to_netcdf-2.10.0: grib_to_n...

# %%
lon_ec = ds_ecmwf['longitude']
lat_ec = ds_ecmwf['latitude']
lon_ec
#ds_ecmwf.t2m[0,,:]
indices_lat = np.where(lat_ec == desired_lat)[0]
indices_lat
# Out:
# array([119])

# %%
indices_lon = np.where(lon_ec == desired_lon)[0]
indices_lon
# Out:
# array([234])

# %%
ds_ecmwf.t2m[0,119,234].values
# Out:
# array(286.42724609)

# %%
import os
import re
import datetime
import xarray as xr

directory = '/lsdf/kit/imk-tro/projects/MOD/Gruppe_Grams/nk2448/2023_FourCastNet/Yangfan/validation/'
filename_pattern = r'fc_cf_\d{8}_\d{2}_sfc\.nc'

files = sorted([f for f in os.listdir(directory) if re.match(filename_pattern, f)])
files
# Out:
# ['fc_cf_20210614_00_sfc.nc',
#  'fc_cf_20210615_00_sfc.nc',
#  'fc_cf_20210616_00_sfc.nc',
#  'fc_cf_20210617_00_sfc.nc',
#  'fc_cf_20210618_00_sfc.nc',
#  'fc_cf_20210619_00_sfc.nc',
#  'fc_cf_20210620_00_sfc.nc',
#  'fc_cf_20210621_00_sfc.nc',
#  'fc_cf_20210622_00_sfc.nc',
#  'fc_cf_20210623_00_sfc.nc',
#  'fc_cf_20210624_00_sfc.nc',
#  'fc_cf_20210625_00_sfc.nc',
#  'fc_cf_20210626_00_sfc.nc',
#  'fc_cf_20210627_00_sfc.nc',
#  'fc_cf_20210628_00_sfc.nc',
#  'fc_cf_20210629_00_sfc.nc',
#  'fc_cf_20210630_00_sfc.nc',
#  'fc_cf_20210701_00_sfc.nc',
#  'fc_cf_20210702_00_sfc.nc',
#  'fc_cf_20210703_00_sfc.nc',
#  'fc_cf_20210704_00_sfc.nc']

# %%
data = []

# %%
for file in files:
    file_path = os.path.join(directory, file)
    # Extract the date from the filename
    #date_str = re.search(r'\d{8}_\d{2}', file).group(0)
    #date = datetime.datetime.strptime(date_str, '%Y%m%d_%H').date()
    # Read the file and extract the desired variable
    ds = xr.open_dataset(file_path)
    variable_data = ds['t2m'] 

    #time_coord = xr.DataArray([date], dims='time1', coords={'time1': [date]})
    #variable_data = variable_data.expand_dims(dim='time1')
    #variable_data = variable_data.assign_coords(time=time_coord)

    data.append(variable_data)

#combined_data = xr.concat(data, dim='time1')
#combined_data
#combined_data[0,:,119,234]
#data

# %%
np.shape(data)
data_array =xr.DataArray(data)
data_array[:,0,0,0]
# Out:
# <xarray.DataArray (dim_0: 21)>
# array([273.72705, 273.479  , 273.2312 , 273.93384, 273.74683, 274.04688,
#        274.479  , 273.27148, 273.32593, 273.1565 , 273.1902 , 273.07666,
#        272.20654, 273.4087 , 273.16016, 272.93628, 273.41748, 273.60327,
#        273.86108, 273.72144, 272.96387], dtype=float32)
# Dimensions without coordinates: dim_0

# %%
fig3 = plt.figure(figsize=(12,3))
plt.plot(time_range_1, data_array[:,0,119,234])
# Set the plot title and labels
plt.title('T2m_ECMWF_Lytton',loc='left')
plt.title('Lead Time = +0h',loc='right')
plt.xlabel('Forecast Initialization')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_1, time_range_1, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot
plt.show()

# %%
ds_fcn_ecmwf = xr.open_dataset('/pfs/work7/workspace/scratch/ab6801-fourcastnet/fourcastnet/with_ecmwf_ic/20210704_00_backtransformed.nc')
ds_fcn_ecmwf
# Out:
# <xarray.Dataset>
# Dimensions:      (phony_dim_2: 21, phony_dim_0: 51, phony_dim_1: 57,
#                   phony_dim_3: 220, phony_dim_4: 480)
# Coordinates:
#   * phony_dim_2  (phony_dim_2) int64 0 1 2 3 4 5 6 7 ... 13 14 15 16 17 18 19 0
#   * phony_dim_0  (phony_dim_0) int64 0 1 2 3 4 5 6 7 ... 43 44 45 46 47 48 49 50
#   * phony_dim_1  (phony_dim_1) int64 0 1 2 3 4 5 6 7 ... 49 50 51 52 53 54 55 56
#   * phony_dim_3  (phony_dim_3) int64 0 1 2 3 4 5 6 ... 214 215 216 217 218 219
#   * phony_dim_4  (phony_dim_4) int64 0 1 2 3 4 5 6 ... 474 475 476 477 478 479
# Data variables:
#     forecast     (phony_dim_0, phony_dim_1, phony_dim_2, phony_dim_3, phony_dim_4) float64 ...

# %%
directory_fcn_ec = '/pfs/work7/workspace/scratch/ab6801-fourcastnet/fourcastnet/with_ecmwf_ic/'
filename_pattern_fcn_ec = r'\d{8}_00_backtransformed\.nc'
#fc_cf_20210615_00_sfc.nc
#20210704_00_backtransformed.nc
files_fcn_ec = sorted([f for f in os.listdir(directory_fcn_ec) if re.match(filename_pattern_fcn_ec, f)])
files_fcn_ec
# Out:
# ['20210614_00_backtransformed.nc',
#  '20210615_00_backtransformed.nc',
#  '20210616_00_backtransformed.nc',
#  '20210617_00_backtransformed.nc',
#  '20210618_00_backtransformed.nc',
#  '20210619_00_backtransformed.nc',
#  '20210620_00_backtransformed.nc',
#  '20210621_00_backtransformed.nc',
#  '20210622_00_backtransformed.nc',
#  '20210623_00_backtransformed.nc',
#  '20210624_00_backtransformed.nc',
#  '20210625_00_backtransformed.nc',
#  '20210626_00_backtransformed.nc',
#  '20210627_00_backtransformed.nc',
#  '20210628_00_backtransformed.nc',
#  '20210629_00_backtransformed.nc',
#  '20210630_00_backtransformed.nc',
#  '20210701_00_backtransformed.nc',
#  '20210702_00_backtransformed.nc',
#  '20210703_00_backtransformed.nc',
#  '20210704_00_backtransformed.nc']

# %%
data_fcn_ec_0 = []
data_fcn_ec_6 = []
data_fcn_ec_12 = []
data_fcn_ec_18 = []
data_fcn_ec_24 = []
data_fcn_ec_30 = []
data_fcn_ec_36 = []
data_fcn_ec_42 = []
data_fcn_ec_48 = []
data_fcn_ec_54 = []
data_fcn_ec_60 = []
data_fcn_ec_66 = []
data_fcn_ec_72 = []
data_fcn_ec_78 = []
data_fcn_ec_84 = []
data_fcn_ec_90 = []
data_fcn_ec_96 = []
data_fcn_ec_102 = []
data_fcn_ec_108 = []
data_fcn_ec_114 = []
data_fcn_ec_120 = []
data_fcn_ec_126 = []
data_fcn_ec_132 = []
data_fcn_ec_138 = []
data_fcn_ec_144 = []
data_fcn_ec_150 = []
data_fcn_ec_156 = []
data_fcn_ec_162 = []
data_fcn_ec_168 = []
data_fcn_ec_174 = []
data_fcn_ec_180 = []
data_fcn_ec_186 = []
data_fcn_ec_192 =  []
data_fcn_ec_198 =  []
data_fcn_ec_204 =  []
data_fcn_ec_210 =  []
data_fcn_ec_216 =  []

for file1 in files_fcn_ec:
    file_path_fcn_ec = os.path.join(directory_fcn_ec, file1)
    # Extract the date from the filename
    date_str = re.search(r'\d{8}', file1).group(0)
    
    date = datetime.datetime.strptime(date_str, '%Y%m%d').date()
    # Read the file and extract the desired variable
    ds_fcn_ec = xr.open_dataset(file_path_fcn_ec)
    variable_data_fcn_ec_0 =  ds_fcn_ec['forecast'][50,0,2,:,:]
    variable_data_fcn_ec_6 =  ds_fcn_ec['forecast'][50,1,2,:,:]
    variable_data_fcn_ec_12 =  ds_fcn_ec['forecast'][50,2,2,:,:]
    variable_data_fcn_ec_18 =  ds_fcn_ec['forecast'][50,3,2,:,:]
    variable_data_fcn_ec_24 =  ds_fcn_ec['forecast'][50,4,2,:,:]
    variable_data_fcn_ec_30 =  ds_fcn_ec['forecast'][50,5,2,:,:]
    variable_data_fcn_ec_36 =  ds_fcn_ec['forecast'][50,6,2,:,:]
    variable_data_fcn_ec_42 =  ds_fcn_ec['forecast'][50,7,2,:,:]
    variable_data_fcn_ec_48 =  ds_fcn_ec['forecast'][50,8,2,:,:]
    variable_data_fcn_ec_54 =  ds_fcn_ec['forecast'][50,9,2,:,:]
    variable_data_fcn_ec_60 =  ds_fcn_ec['forecast'][50,10,2,:,:]
    variable_data_fcn_ec_66 =  ds_fcn_ec['forecast'][50,11,2,:,:]
    variable_data_fcn_ec_72 =  ds_fcn_ec['forecast'][50,12,2,:,:]
    variable_data_fcn_ec_78 =  ds_fcn_ec['forecast'][50,13,2,:,:]
    variable_data_fcn_ec_84 =  ds_fcn_ec['forecast'][50,14,2,:,:]
    variable_data_fcn_ec_90 =  ds_fcn_ec['forecast'][50,15,2,:,:]
    variable_data_fcn_ec_96 =  ds_fcn_ec['forecast'][50,16,2,:,:]
    variable_data_fcn_ec_102 =  ds_fcn_ec['forecast'][50,17,2,:,:]
    variable_data_fcn_ec_108 =  ds_fcn_ec['forecast'][50,18,2,:,:]
    variable_data_fcn_ec_114 =  ds_fcn_ec['forecast'][50,19,2,:,:]
    variable_data_fcn_ec_120 =  ds_fcn_ec['forecast'][50,20,2,:,:]
    variable_data_fcn_ec_126 =  ds_fcn_ec['forecast'][50,21,2,:,:]
    variable_data_fcn_ec_132 =  ds_fcn_ec['forecast'][50,22,2,:,:]
    variable_data_fcn_ec_138 =  ds_fcn_ec['forecast'][50,23,2,:,:]
    variable_data_fcn_ec_144 =  ds_fcn_ec['forecast'][50,24,2,:,:]
    variable_data_fcn_ec_150 =  ds_fcn_ec['forecast'][50,25,2,:,:]
    variable_data_fcn_ec_156 =  ds_fcn_ec['forecast'][50,26,2,:,:]
    variable_data_fcn_ec_162 =  ds_fcn_ec['forecast'][50,27,2,:,:]
    variable_data_fcn_ec_168 =  ds_fcn_ec['forecast'][50,28,2,:,:]
    variable_data_fcn_ec_174 =  ds_fcn_ec['forecast'][50,29,2,:,:]
    variable_data_fcn_ec_180 =  ds_fcn_ec['forecast'][50,30,2,:,:]
    variable_data_fcn_ec_186 =  ds_fcn_ec['forecast'][50,31,2,:,:]
    variable_data_fcn_ec_192 =  ds_fcn_ec['forecast'][50,32,2,:,:]
    variable_data_fcn_ec_198 =  ds_fcn_ec['forecast'][50,33,2,:,:]
    variable_data_fcn_ec_204 =  ds_fcn_ec['forecast'][50,34,2,:,:]
    variable_data_fcn_ec_210 =  ds_fcn_ec['forecast'][50,35,2,:,:]
    variable_data_fcn_ec_216 =  ds_fcn_ec['forecast'][50,36,2,:,:]
    #phony_dim_2: 21phony_dim_0: 51phony_dim_1: 57phony_dim_3: 220phony_dim_4: 480
    #data_fcn_ec[0:20] = variable_data_fcn_ec
    #time_coord = xr.DataArray([date], dims='time1', coords={'time1': [date]})
    #variable_data_fcn_ec = variable_data_fcn_ec.expand_dims(dim='time1')
    #variable_data = variable_data.assign_coords(time=time_coord)
    #dataset1['Time'] = pd.to_datetime(dataset1['Date'])
    data_fcn_ec_0.append(variable_data_fcn_ec_0)
    data_fcn_ec_6.append(variable_data_fcn_ec_6)
    data_fcn_ec_12.append(variable_data_fcn_ec_12)
    data_fcn_ec_18.append(variable_data_fcn_ec_18)
    data_fcn_ec_24.append(variable_data_fcn_ec_24)
    data_fcn_ec_30.append(variable_data_fcn_ec_30)
    data_fcn_ec_36.append(variable_data_fcn_ec_36)
    data_fcn_ec_42.append(variable_data_fcn_ec_42)
    data_fcn_ec_48.append(variable_data_fcn_ec_48)
    data_fcn_ec_54.append(variable_data_fcn_ec_54)
    data_fcn_ec_60.append(variable_data_fcn_ec_60)
    data_fcn_ec_66.append(variable_data_fcn_ec_66)
    data_fcn_ec_72.append(variable_data_fcn_ec_72)
    data_fcn_ec_78.append(variable_data_fcn_ec_78)
    data_fcn_ec_84.append(variable_data_fcn_ec_84)
    data_fcn_ec_90.append(variable_data_fcn_ec_90)
    data_fcn_ec_96.append(variable_data_fcn_ec_96)
    data_fcn_ec_102.append(variable_data_fcn_ec_102)
    data_fcn_ec_108.append(variable_data_fcn_ec_108)
    data_fcn_ec_114.append(variable_data_fcn_ec_114)
    data_fcn_ec_120.append(variable_data_fcn_ec_120)
    data_fcn_ec_126.append(variable_data_fcn_ec_126)
    data_fcn_ec_132.append(variable_data_fcn_ec_132)
    data_fcn_ec_138.append(variable_data_fcn_ec_138)
    data_fcn_ec_144.append(variable_data_fcn_ec_144)
    data_fcn_ec_150.append(variable_data_fcn_ec_150)
    data_fcn_ec_156.append(variable_data_fcn_ec_156)
    data_fcn_ec_162.append(variable_data_fcn_ec_162)
    data_fcn_ec_168.append(variable_data_fcn_ec_168)
    data_fcn_ec_174.append(variable_data_fcn_ec_174)
    data_fcn_ec_180.append(variable_data_fcn_ec_180)
    data_fcn_ec_186.append(variable_data_fcn_ec_186)
    data_fcn_ec_192.append(variable_data_fcn_ec_192)
    data_fcn_ec_198.append(variable_data_fcn_ec_198)
    data_fcn_ec_204.append(variable_data_fcn_ec_204)
    data_fcn_ec_210.append(variable_data_fcn_ec_210)
    data_fcn_ec_216.append(variable_data_fcn_ec_216)
    
    
#type(data_fcn_ec)
#data_fcn_ec
#ar = np.array(data_fcn_ec)

#combined_data = xr.concat(data_fcn_ec, dim=None)
#combined_data
#combined_data[0,:,119,234]
#data_array_fcn_ec =xr.merge(data_fcn_ec)
#np.shape(data_fcn_ec)
#data_array_fcn_ec = xr.concat(data_fcn_ec, dim='time')
data_array_fcn_ec_0 =xr.DataArray(data_fcn_ec_0)
data_array_fcn_ec_6 =xr.DataArray(data_fcn_ec_6)
data_array_fcn_ec_12 =xr.DataArray(data_fcn_ec_12)
data_array_fcn_ec_18 =xr.DataArray(data_fcn_ec_18)
data_array_fcn_ec_24 =xr.DataArray(data_fcn_ec_24)
data_array_fcn_ec_30 =xr.DataArray(data_fcn_ec_30)
data_array_fcn_ec_36 =xr.DataArray(data_fcn_ec_36)
data_array_fcn_ec_42 =xr.DataArray(data_fcn_ec_42)
data_array_fcn_ec_48 =xr.DataArray(data_fcn_ec_48)
data_array_fcn_ec_54 =xr.DataArray(data_fcn_ec_54)
data_array_fcn_ec_60 =xr.DataArray(data_fcn_ec_60)
data_array_fcn_ec_66 =xr.DataArray(data_fcn_ec_66)
data_array_fcn_ec_72 =xr.DataArray(data_fcn_ec_72)
data_array_fcn_ec_78 =xr.DataArray(data_fcn_ec_78)
data_array_fcn_ec_84 =xr.DataArray(data_fcn_ec_84)
data_array_fcn_ec_90 =xr.DataArray(data_fcn_ec_90)
data_array_fcn_ec_96 =xr.DataArray(data_fcn_ec_96)
data_array_fcn_ec_102 =xr.DataArray(data_fcn_ec_102)
data_array_fcn_ec_108 =xr.DataArray(data_fcn_ec_108)
data_array_fcn_ec_114 =xr.DataArray(data_fcn_ec_114)
data_array_fcn_ec_120 =xr.DataArray(data_fcn_ec_120)
data_array_fcn_ec_126 =xr.DataArray(data_fcn_ec_126)
data_array_fcn_ec_132 =xr.DataArray(data_fcn_ec_132)
data_array_fcn_ec_138 =xr.DataArray(data_fcn_ec_102)
data_array_fcn_ec_144 =xr.DataArray(data_fcn_ec_108)
data_array_fcn_ec_150 =xr.DataArray(data_fcn_ec_114)
data_array_fcn_ec_156 =xr.DataArray(data_fcn_ec_120)
data_array_fcn_ec_16 =xr.DataArray(data_fcn_ec_126)
data_array_fcn_ec_132 =xr.DataArray(data_fcn_ec_132)
data_array_fcn_ec_102 =xr.DataArray(data_fcn_ec_102)
data_array_fcn_ec_108 =xr.DataArray(data_fcn_ec_108)
data_array_fcn_ec_114 =xr.DataArray(data_fcn_ec_114)
data_array_fcn_ec_120 =xr.DataArray(data_fcn_ec_120)
data_array_fcn_ec_126 =xr.DataArray(data_fcn_ec_126)
data_array_fcn_ec_132 =xr.DataArray(data_fcn_ec_132)
#data_array_fcn_ec

# %%
type(data_fcn_ec_6)
np.shape(data_fcn_ec_6)
# Out:
# (21, 220, 480)

# %%
def make_plots_ts_ft(time_range,ds_fcn_era5,ds_era5,ds_fcn_ecmwf,ds_ecmwf,leadtime,path):
    fig7 = plt.figure(figsize=(12,3))

    plt.plot(time_range, ds_fcn_era5,label=f"Fourcastnet(ERA5)with lead time ={leadtime}")
    plt.plot(time_range, ds_era5,label="ERA5")
    plt.plot(time_range, ds_fcn_ecmwf,label=f"Fourcastnet(ECMWF) with lead time ={leadtime}")
    plt.plot(time_range, ds_ecmwf,label=f"ECMWF with lead time ={leadtime}")
    plt.legend(loc="upper left")
    # Set the plot title and labels
    plt.title('T2m_Lytton')
    #plt.title('Lead Time = +6h',loc='right')
    plt.xlabel('Forecast Time')
    plt.ylabel('Temperature(K)')
    plt.xticks(time_range, time_range, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
    plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

    plt.savefig(path, bbox_inches='tight',dpi=100)
    plt.show()

# %%
fig4 = plt.figure(figsize=(12,3))

plt.plot(time_range_1, data_array_fcn_ec_6[:,119,234])
#
# Set the plot title and labels
plt.title('T2m_Fourcastnet(ECMWF)_Lytton',loc='left')
plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Initialization')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_1, time_range_1, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot
plt.show()

# %%
#with lead time = 0h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig6 = plt.figure(figsize=(12,3))

plt.plot(time_range_1, ds_fcn_21.forecast[:,0,0,2,119,234],label="Fourcastnet(ERA5)_ground truth")
plt.plot(time_range_1, time_series_data_0h,label="ERA5")
plt.plot(time_range_1, data_array[:,0,119,234],label="ECMWF with lead time =+0h")
#plt.plot(time_range_1, data_array_fcn_ec[:,119,234],label="Fourcastnet(ECMWF)")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_1, time_range_1, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_0h_ts_2.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 6h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig7 = plt.figure(figsize=(12,3))

plt.plot(time_range_2, ds_fcn_21.forecast[:,0,1,2,119,234],label="Fourcastnet(ERA5)with lead time =+6h")
plt.plot(time_range_2, time_series_data_6h,label="ERA5")
plt.plot(time_range_2, data_array_fcn_ec_6[:,119,234],label="Fourcastnet(ECMWF) with lead time =+6h")
plt.plot(time_range_2, data_array[:,1,119,234],label="ECMWF with lead time =+6h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_2, time_range_2, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_6h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 12h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig8 = plt.figure(figsize=(12,3))

plt.plot(time_range_3, ds_fcn_21.forecast[:,0,2,2,119,234],label="Fourcastnet(ERA5)with lead time =+12h")
plt.plot(time_range_3, time_series_data_12h,label="ERA5")
plt.plot(time_range_3, data_array_fcn_ec_12[:,119,234],label="Fourcastnet(ECMWF) with lead time =+12h")
plt.plot(time_range_3, data_array[:,2,119,234],label="ECMWF with lead time =+12h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_3, time_range_3, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_12h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 18h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig9 = plt.figure(figsize=(12,3))

plt.plot(time_range_4, ds_fcn_21.forecast[:,0,3,2,119,234],label="Fourcastnet(ERA5)with lead time =+18h")
plt.plot(time_range_4, time_series_data_18h,label="ERA5")
plt.plot(time_range_4, data_array_fcn_ec_18[:,119,234],label="Fourcastnet(ECMWF) with lead time =+18h")
plt.plot(time_range_4, data_array[:,3,119,234],label="ECMWF with lead time =+18h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_4, time_range_4, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_18h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 24h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig10 = plt.figure(figsize=(12,3))

plt.plot(time_range_5, ds_fcn_21.forecast[:,0,4,2,119,234],label="Fourcastnet(ERA5)with lead time =+24h")
plt.plot(time_range_5, time_series_data_24h,label="ERA5")
plt.plot(time_range_5, data_array_fcn_ec_24[:,119,234],label="Fourcastnet(ECMWF) with lead time =+24h")
plt.plot(time_range_5, data_array[:,4,119,234],label="ECMWF with lead time =+24h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_5, time_range_5, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_24h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 30h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_6, ds_fcn_21.forecast[:,0,5,2,119,234],label="Fourcastnet(ERA5)with lead time =+30h")
plt.plot(time_range_6, time_series_data_30h,label="ERA5")
plt.plot(time_range_6, data_array_fcn_ec_30[:,119,234],label="Fourcastnet(ECMWF) with lead time =+30h")
plt.plot(time_range_6, data_array[:,5,119,234],label="ECMWF with lead time =+30h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_6, time_range_6, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_30h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 36h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_7, ds_fcn_21.forecast[:,0,6,2,119,234],label="Fourcastnet(ERA5)with lead time =+36h")
plt.plot(time_range_7, time_series_data_36h,label="ERA5")
plt.plot(time_range_7, data_array_fcn_ec_36[:,119,234],label="Fourcastnet(ECMWF) with lead time =+36h")
plt.plot(time_range_7, data_array[:,6,119,234],label="ECMWF with lead time =+36h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_7, time_range_7, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the plot

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_36h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 42h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_8, ds_fcn_21.forecast[:,0,7,2,119,234],label="Fourcastnet(ERA5)with lead time =+42h")
plt.plot(time_range_8, time_series_data_42h,label="ERA5")
plt.plot(time_range_8, data_array_fcn_ec_42[:,119,234],label="Fourcastnet(ECMWF) with lead time =+42h")
plt.plot(time_range_8, data_array[:,7,119,234],label="ECMWF with lead time =+42h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_8, time_range_8, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_42h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 48h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_9, ds_fcn_21.forecast[:,0,8,2,119,234],label="Fourcastnet(ERA5)with lead time =+48h")
plt.plot(time_range_9, time_series_data_48h,label="ERA5")
plt.plot(time_range_9, data_array_fcn_ec_48[:,119,234],label="Fourcastnet(ECMWF) with lead time =+48h")
plt.plot(time_range_9, data_array[:,8,119,234],label="ECMWF with lead time =+48h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_9, time_range_9, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_48h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 54h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_10, ds_fcn_21.forecast[:,0,9,2,119,234],label="Fourcastnet(ERA5)with lead time =+54h")
plt.plot(time_range_10, time_series_data_54h,label="ERA5")
plt.plot(time_range_10, data_array_fcn_ec_54[:,119,234],label="Fourcastnet(ECMWF) with lead time =+54h")
plt.plot(time_range_10, data_array[:,9,119,234],label="ECMWF with lead time =+54h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_10, time_range_10, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_54h_ts.png', bbox_inches='tight',dpi=100)
plt.show()

# %%
#with lead time = 60h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_11, ds_fcn_21.forecast[:,0,10,2,119,234],label="Fourcastnet(ERA5)with lead time =+60h")
plt.plot(time_range_11, time_series_data_60h,label="ERA5")
plt.plot(time_range_11, data_array_fcn_ec_60[:,119,234],label="Fourcastnet(ECMWF) with lead time =+60h")
plt.plot(time_range_11, data_array[:,10,119,234],label="ECMWF with lead time =+60h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_11, time_range_11, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_60h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 66h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_12, ds_fcn_21.forecast[:,0,11,2,119,234],label="Fourcastnet(ERA5)with lead time =+66h")
plt.plot(time_range_12, time_series_data_66h,label="ERA5")
plt.plot(time_range_12, data_array_fcn_ec_66[:,119,234],label="Fourcastnet(ECMWF) with lead time =+66h")
plt.plot(time_range_12, data_array[:,11,119,234],label="ECMWF with lead time =+66h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_12, time_range_12, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_66h_ts.png', bbox_inches='tight',dpi=100)    
plt.show()

# %%
#with lead time = 72h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_13, ds_fcn_21.forecast[:,0,12,2,119,234],label="Fourcastnet(ERA5)with lead time =+72h")
plt.plot(time_range_13, time_series_data_72h,label="ERA5")
plt.plot(time_range_13,data_array_fcn_ec_72[:,119,234],label="Fourcastnet(ECMWF) with lead time =+72h")
plt.plot(time_range_13, data_array[:,12,119,234],label="ECMWF with lead time =+72h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_13, time_range_13, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_72h_ts.png', bbox_inches='tight',dpi=100)   
plt.show()

# %%
#with lead time = 78h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_14, ds_fcn_21.forecast[:,0,13,2,119,234],label="Fourcastnet(ERA5)with lead time =+78h")
plt.plot(time_range_14, time_series_data_78h,label="ERA5")
plt.plot(time_range_14, data_array_fcn_ec_78[:,119,234],label="Fourcastnet(ECMWF) with lead time =+78h")
plt.plot(time_range_14, data_array[:,13,119,234],label="ECMWF with lead time =+78h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_14, time_range_14, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_78h_ts.png', bbox_inches='tight',dpi=100)  
plt.show()

# %%
#with lead time = 84h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_15, ds_fcn_21.forecast[:,0,14,2,119,234],label="Fourcastnet(ERA5)with lead time =+84h")
plt.plot(time_range_15, time_series_data_84h,label="ERA5")
plt.plot(time_range_15, data_array_fcn_ec_84[:,119,234],label="Fourcastnet(ECMWF) with lead time =+84h")
plt.plot(time_range_15, data_array[:,14,119,234],label="ECMWF with lead time =+84h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_15, time_range_15, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_84h_ts.png', bbox_inches='tight',dpi=100)   
plt.show()

# %%
#with lead time = 90h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_16, ds_fcn_21.forecast[:,0,15,2,119,234],label="Fourcastnet(ERA5)with lead time =+90h")
plt.plot(time_range_16, time_series_data_90h,label="ERA5")
plt.plot(time_range_16, data_array_fcn_ec_90[:,119,234],label="Fourcastnet(ECMWF) with lead time =+90h")
plt.plot(time_range_16, data_array[:,15,119,234],label="ECMWF with lead time =+90h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_16, time_range_16, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_90h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 96h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_17, ds_fcn_21.forecast[:,0,16,2,119,234],label="Fourcastnet(ERA5)with lead time =+96h")
plt.plot(time_range_17, time_series_data_96h,label="ERA5")
plt.plot(time_range_17, data_array_fcn_ec_96[:,119,234],label="Fourcastnet(ECMWF) with lead time =+96h")
plt.plot(time_range_17, data_array[:,16,119,234],label="ECMWF with lead time =+96h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_17, time_range_17, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_96h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 102h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_18, ds_fcn_21.forecast[:,0,17,2,119,234],label="Fourcastnet(ERA5)with lead time =+102h")
plt.plot(time_range_18, time_series_data_102h,label="ERA5")
plt.plot(time_range_18, data_array_fcn_ec_102[:,119,234],label="Fourcastnet(ECMWF) with lead time =+102h")
plt.plot(time_range_18, data_array[:,17,119,234],label="ECMWF with lead time =+102h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_18, time_range_18, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_102h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 108h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_19, ds_fcn_21.forecast[:,0,18,2,119,234],label="Fourcastnet(ERA5)with lead time =+108h")
plt.plot(time_range_19, time_series_data_108h,label="ERA5")
plt.plot(time_range_19, data_array_fcn_ec_108[:,119,234],label="Fourcastnet(ECMWF) with lead time =+108h")
plt.plot(time_range_19, data_array[:,18,119,234],label="ECMWF with lead time =+108h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_19, time_range_19, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_108h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 114h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_20, ds_fcn_21.forecast[:,0,19,2,119,234],label="Fourcastnet(ERA5)with lead time =+114h")
plt.plot(time_range_20, time_series_data_114h,label="ERA5")
plt.plot(time_range_20, data_array_fcn_ec_114[:,119,234],label="Fourcastnet(ECMWF) with lead time =+114h")
plt.plot(time_range_20, data_array[:,19,119,234],label="ECMWF with lead time =+114h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_20, time_range_20, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_114h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 120h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_21, ds_fcn_21.forecast[:,0,20,2,119,234],label="Fourcastnet(ERA5)with lead time =+120h")
plt.plot(time_range_21, time_series_data_120h,label="ERA5")
plt.plot(time_range_21, data_array_fcn_ec_120[:,119,234],label="Fourcastnet(ECMWF) with lead time =+120h")
plt.plot(time_range_21, data_array[:,20,119,234],label="ECMWF with lead time =+120h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_21, time_range_21, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_120h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 126h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_22, ds_fcn_21.forecast[:,0,21,2,119,234],label="Fourcastnet(ERA5)with lead time =+126h")
plt.plot(time_range_22, time_series_data_126h,label="ERA5")
plt.plot(time_range_22, data_array_fcn_ec_126[:,119,234],label="Fourcastnet(ECMWF) with lead time =+126h")
plt.plot(time_range_22, data_array[:,21,119,234],label="ECMWF with lead time =+126h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_22, time_range_22, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_126h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 132h 
#ERA5,Fourcastnet(ERA5),Fourcastnet(ECMWF)

fig11 = plt.figure(figsize=(12,3))

plt.plot(time_range_23, ds_fcn_21.forecast[:,0,22,2,119,234],label="Fourcastnet(ERA5)with lead time =+132h")
plt.plot(time_range_23, time_series_data_132h,label="ERA5")
plt.plot(time_range_23, data_array_fcn_ec_132[:,119,234],label="Fourcastnet(ECMWF) with lead time =+132h")
plt.plot(time_range_23, data_array[:,22,119,234],label="ECMWF with lead time =+132h")
plt.legend(loc="upper left")
# Set the plot title and labels
plt.title('T2m_Lytton')
#plt.title('Lead Time = +6h',loc='right')
plt.xlabel('Forecast Time')
plt.ylabel('Temperature(K)')

plt.xticks(time_range_23, time_range_23, rotation=45)
#plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) # Adjust the date format as needed
plt.xticks(rotation=45)
#make the x axis tick evenly distributed
#point out the highest point?
#plot seperately or together?
# Display the 

plt.savefig('/home/kit/imk-tro/gj5173/plots_ts/T2m_132h_ts.png', bbox_inches='tight',dpi=100) 
plt.show()

# %%
#with lead time = 138h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 144h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 150h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 156h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 162h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 168h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 174h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 180h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 186h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 192h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 198h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 204h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 210h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
#with lead time = 216h 
make_plots_ts_ft(time_range_2,ds_fcn_21.forecast[:,0,23,2,119,234],time_series_data_138h,data_array_fcn_ec_138[:,119,234],data_array[:,23,119,234],'+138h','/home/kit/imk-tro/gj5173/plots_ts/T2m_138h_ts.png')
