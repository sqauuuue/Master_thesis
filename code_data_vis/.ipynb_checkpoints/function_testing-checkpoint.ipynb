# %%
from function_basic import load_data_1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from function_basic import load_data_1
#
# ImportError: cannot import name 'load_data_1' from 'function_basic' (/pfs/data5/home/kit/imk-tro/gj5173/codes here/function_basic.py)

# %%
def load_data(path):
    """
        Given a path, read the file and return the contents.

        Arguments:
        path (string) : File path with .pkl extension
    """
    ds_era5 = xr.open_dataset(path+'/era5/2021.h5',engine=engine_type)
    #ds_fcn_era = xr.open_dataset(path,engine=engine_type)
    #ds_fcn_ec =  xr.open_dataset(path,engine=engine_type)
    #ds_ec =  xr.open_dataset(path,engine=engine_type)
    return ds_era5

# %%
ds_era = load_data_1('/lsdf/kit/imk-tro/projects/MOD/Gruppe_Knippertz/ey9908/tmp_Yangfan/data/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 ds_era = load_data('/lsdf/kit/imk-tro/projects/MOD/Gruppe_Knippertz/ey9908/tmp_Yangfan/data/')
#
# Cell In[28], line 8, in load_data(path)
#       1 def load_data(path):
#       2     """
#       3         Given a path, read the file and return the contents.
#       4
#       5         Arguments:
#       6         path (string) : File path with .pkl extension
#       7     """
# ----> 8     ds_era5 = xr.open_dataset(path+'/era5/2021.h5',engine=engine_type)
#       9     #ds_fcn_era = xr.open_dataset(path,engine=engine_type)
#      10     #ds_fcn_ec =  xr.open_dataset(path,engine=engine_type)
#      11     #ds_ec =  xr.open_dataset(path,engine=engine_type)
#      12     return ds_era5
#
# NameError: name 'xr' is not defined

# %%
# Out:
# <xarray.Dataset>
# Dimensions:  (phony_dim_0: 1460, phony_dim_1: 20, phony_dim_2: 721,
#               phony_dim_3: 1440)
# Dimensions without coordinates: phony_dim_0, phony_dim_1, phony_dim_2,
#                                 phony_dim_3
# Data variables:
#     fields   (phony_dim_0, phony_dim_1, phony_dim_2, phony_dim_3) float32 ...
